# %%
import pandas as pd
import numpy as np

df=pd.read_csv("C:/Users/Administrator/Documents/python/class/Jupiter notebooks/DataSets/terror/Store.csv",encoding="latin")
print(df)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2013-152156   11/9/2013  11/12/2013    Second Class
# 1          2  CA-2013-152156   11/9/2013  11/12/2013    Second Class
# 2          3  CA-2013-138688   6/13/2013   6/17/2013    Second Class
# 3          4  US-2012-108966  10/11/2012  10/18/2012  Standard Class
# 4          5  US-2012-108966  10/11/2012  10/18/2012  Standard Class
# 5          6  CA-2011-115812    6/9/2011   6/14/2011  Standard Class
# 6          7  CA-2011-115812    6/9/2011   6/14/2011  Standard Class
# 7          8  CA-2011-115812    6/9/2011   6/14/2011  Standard Class
# 8          9  CA-2011-115812    6/9/2011   6/14/2011  Standard Class
# 9         10  CA-2011-115812    6/9/2011   6/14/2011  Standard Class
# 10        11  CA-2011-115812    6/9/2011   6/14/2011  Standard Class
# 11        12  CA-2011-115812    6/9/2011   6/14/2011  Standard Class
# 12        13  CA-2014-114412   4/16/2014   4/21/2014  Standard Class
# ...

# %%
#•	How many unique cities are the orders being delivered to

df.City.unique()
# Out:
# array(['Henderson', 'Los Angeles', 'Fort Lauderdale', 'Concord',
#        'Seattle', 'Fort Worth', 'Madison', 'West Jordan', 'San Francisco',
#        'Fremont', 'Philadelphia', 'Orem', 'Houston', 'Richardson',
#        'Naperville', 'Melbourne', 'Eagan', 'Westland', 'Dover',
#        'New Albany', 'New York City', 'Troy', 'Chicago', 'Gilbert',
#        'Springfield', 'Jackson', 'Memphis', 'Decatur', 'Durham',
#        'Columbia', 'Rochester', 'Minneapolis', 'Portland', 'Saint Paul',
#        'Aurora', 'Charlotte', 'Orland Park', 'Urbandale', 'Columbus',
#        'Bristol', 'Wilmington', 'Bloomington', 'Phoenix', 'Roseville',
#        'Independence', 'Pasadena', 'Newark', 'Franklin', 'Scottsdale',
#        'San Jose', 'Edmond', 'Carlsbad', 'San Antonio', 'Monroe',
#        'Fairfield', 'Grand Prairie', 'Redlands', 'Hamilton', 'Westfield',
#        'Akron', 'Denver', 'Dallas', 'Whittier', 'Saginaw', 'Medina',
#        'Dublin', 'Detroit', 'Tampa', 'Santa Clara', 'Lakeville',
# ...

# %%
#•	What is the total quantity sold in the East Region?
print(df.loc[df['Region']=='East']['Quantity'].count())
# Out:
# 2848

# %%
#•	Find the sum of the quantity sold in the East Region

print(df.loc[df['Region']=='East']['Quantity'].sum())
# Out:
# 10618

# %%
#•	In the south region sort the sales in decreasing order

print(df.loc[df['Region']=='South'].sort_values('Sales',ascending=False))
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2697    2698  CA-2011-145317   3/18/2011   3/23/2011  Standard Class
# 8488    8489  CA-2013-158841    2/2/2013    2/4/2013    Second Class
# 683      684  US-2014-168116   11/5/2014   11/5/2014        Same Day
# 509      510  CA-2012-145352   3/16/2012   3/22/2012  Standard Class
# 4297    4298  CA-2014-129021   8/24/2014   8/27/2014    Second Class
# 9639    9640  CA-2012-116638   1/28/2012   1/31/2012    Second Class
# 3280    3281  CA-2011-102988    4/5/2011    4/9/2011    Second Class
# 7583    7584  CA-2011-163223   3/21/2011   3/25/2011  Standard Class
# 4093    4094  CA-2012-102491   8/24/2012   8/28/2012  Standard Class
# 1454    1455  CA-2013-133711  11/27/2013  11/30/2013     First Class
# 5562    5563  CA-2014-133263    4/1/2014    4/3/2014    Second Class
# 8312    8313  US-2014-105935   1/27/2014    2/1/2014  Standard Class
# 8236    8237  CA-2014-102204    5/2/2014    5/7/2014  Standard Class
# ...

# %%
#•	Find the mean of quantity for every region

df.groupby('Region')['Quantity'].mean()
# Out:
# Region
# Central    3.779595
# East       3.728230
# South      3.832716
# West       3.829535
# Name: Quantity, dtype: float64

# %%
#•	Find the mean of sales for every category

df.groupby('Category')['Sales'].mean()
# Out:
# Category
# Furniture          349.834887
# Office Supplies    119.324101
# Technology         452.709276
# Name: Sales, dtype: float64

# %%
#•	Find the max, min, sum of sales and profit for every category
df.groupby('Category')[['Sales','Profit']].agg(['max','min','sum'])
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead tr th {
#         text-align: left;
#     }
#
#     .dataframe thead tr:last-of-type th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="3" halign="left">Sales</th>
#       <th colspan="3" halign="left">Profit</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>max</th>
#       <th>min</th>
#       <th>sum</th>
#       <th>max</th>
#       <th>min</th>
#       <th>sum</th>
#     </tr>
#     <tr>
#       <th>Category</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Furniture</th>
#       <td>4416.174</td>
#       <td>1.892</td>
# ...

# %%
#•	Find sum of sales and max profit for every segment

df.groupby('Segment').agg({'Sales':np.sum,'Profit':np.max})
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Sales</th>
#       <th>Profit</th>
#     </tr>
#     <tr>
#       <th>Segment</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Consumer</th>
#       <td>1.161401e+06</td>
#       <td>6719.9808</td>
#     </tr>
#     <tr>
#       <th>Corporate</th>
#       <td>7.061464e+05</td>
#       <td>8399.9760</td>
#     </tr>
#     <tr>
#       <th>Home Office</th>
#       <td>4.296531e+05</td>
#       <td>3919.9888</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#•	For every segment find the mean of the discount

df.groupby('Segment')['Discount'].mean()
# Out:
# Segment
# Consumer       0.158141
# Corporate      0.158228
# Home Office    0.147128
# Name: Discount, dtype: float64

# %%
#•	For every segment find the most profitable customers

df1=df.groupby(['Segment'])['Profit'].max()
df1
df2=df.Profit
df[['Segment','Customer Name','Profit']][np.in1d(df2,df1)]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Segment</th>
#       <th>Customer Name</th>
#       <th>Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2623</th>
#       <td>Home Office</td>
#       <td>Tom Ashbrook</td>
#       <td>3919.9888</td>
#     </tr>
#     <tr>
#       <th>6826</th>
#       <td>Corporate</td>
#       <td>Tamara Chand</td>
#       <td>8399.9760</td>
#     </tr>
#     <tr>
#       <th>8153</th>
#       <td>Consumer</td>
#       <td>Raymond Buch</td>
#       <td>6719.9808</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#•	What are the top 5 categories that give maximum profit?
df.groupby('Sub-Category')['Profit'].max().reset_index().sort_values('Profit',ascending=False).head(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Sub-Category</th>
#       <th>Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>6</th>
#       <td>Copiers</td>
#       <td>8399.9760</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Binders</td>
#       <td>4946.3700</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Machines</td>
#       <td>2799.9840</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Phones</td>
#       <td>1228.1787</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Bookcases</td>
#       <td>1013.1270</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#•	What is the Total Sales, Quantity, Discount, Profit across Total US

df.groupby('Country')[['Sales','Quantity','Discount','Profit']].sum()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Sales</th>
#       <th>Quantity</th>
#       <th>Discount</th>
#       <th>Profit</th>
#     </tr>
#     <tr>
#       <th>Country</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>United States</th>
#       <td>2.297201e+06</td>
#       <td>37873</td>
#       <td>1561.09</td>
#       <td>286397.0217</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#•	How many times has it taken more than 5 days from placing an order to shipping
df['Order Date']=pd.to_datetime(df['Order Date'])
df['Ship Date']=pd.to_datetime(df['Ship Date'])
df['Interval']=df['Ship Date']-df['Order Date']
print(df[df.Interval > '5 days']['Interval'].count())
# Out:
# 1822

# %%
#•	Find the total number of orders in every category which has been shipped with a duration > 5 days
df['Order Date']=pd.to_datetime(df['Order Date'])
df['Ship Date']=pd.to_datetime(df['Ship Date'])
df['Interval']=df['Ship Date']-df['Order Date']
df1=df[df.Interval >'5 days']
df1.groupby('Category')['Order Date'].count().reset_index()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Category</th>
#       <th>Order Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Furniture</td>
#       <td>365</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Office Supplies</td>
#       <td>1131</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Technology</td>
#       <td>326</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#•	What’s the percentage of items which has been shipped within 5 days
print(df[df.Interval < '5 days']['Order ID'].count()/df.shape[0]*100)
#df1["Percent"]
# Out:
# 60.00600360216129

# %%
#•	What’s the percentage of items which has been shipped after 5 days

print(df[df.Interval > '5 days']['Order ID'].count()/df.shape[0]*100)
# Out:
# 18.230938563137883
